# %%
sum = 40
sum = 40.5
var1 = " Test"
var2 = True

print(sum,var1,var2)
# Out:
# 40.5  Test True

# %%
myName = "IIIT Dharwad"
combination = myName + " " + myName
print(combination)
# Out:
# IIIT Dharwad IIIT Dharwad

# %%
mySite,myBlog = "https://www.hobbybytes.in","https://www.hobbybytes.com"

print(mySite,myBlog)
# Out:
# https://www.hobbybytes.in https://www.hobbybytes.com

# %%
mySite,myBlog = "https://www.hobbybytes.in"
print(mySite,myBlog)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-8c77334d3301> in <module>()
# ----> 1 mySite,myBlog = "https://www.hobbybytes.in"
#       2 print(mySite,myBlog)
#
# ValueError: too many values to unpack (expected 2)

# %%
courseName=" OOP Course"
students=125
credits=4

print(students)
print(courseName)
print(credits)
# Out:
# 125
#  OOP Course
# 4

# %%
m = (1 == True)
y = (1 == False)
l = True + 5
m = False + 40

print("m is", m)
print("y is", y)
print("l:", l)
print("m:", m)
# Out:
# m is 40
# y is False
# l: 6
# m: 40

# %%
  food = "Available"
junkfood = None

def menu(x):
    if x == food:
        print(food)
    else:
        print(not available)

menu(food)
menu(junkfood)
# Out:
#   File "<ipython-input-14-959d7cbe8dc2>", line 2
#     food = "Available"
#     ^
# IndentationError: unexpected indent

# %%
# Note:  different values for the id

b = 2      # refer to same id

print('id(2) =', id(2))

print('id(b) =', id(b))


b = b+1

print('id(b) =', id(b))

print('id(3) =', id(3))    # refer to different id
# Out:
# id(2) = 94501054081568
# id(b) = 94501054081568
# id(b) = 94501054081600
# id(3) = 94501054081600
